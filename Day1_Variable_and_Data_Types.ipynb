# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhamdiwakarkadam/python-for-beginners/blob/main/Day1_Variable_and_Data_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello shubham")
# Out:
# hello shubham

# %%
print("my age is 24")
# Out:
# my age is 24

# %%
print(24+22)
# Out:
# 46

# %% [markdown]
# **variable**

# %%
name = "shubham"   #string
age = 23           #integer
price = 25.99      #floating


print(name)
print(age)
print(price)

print("My name is : ", name)
print("My age is : ", age)

age2 = age

print(age2)
# Out:
# shubham
# 23
# 25.99
# My name is :  shubham
# My age is :  23
# 23

# %% [markdown]
# **Data Types**
#
#
# 1.   Integer :  +ve, -ve , 0 , "(25,-25,0")
# 2.   String  : 'shubhamkadam',  "Shubham KAdam" , '''shubham'''
# 3.   float   : 3.99 , 2.5, 6.9 , 9.0 , 10.00
# 4.   Boolean : True , False
# 5.   None    : no value

# %%
print(type(name))
print(type(age))
print(type(price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# **Keywords**
#
# and\
# as\
# assert\
# break\
# class\
# continue\
# def\
# del\
# elif\
# else\
# except\
# finally\
# false\
# for\
# from\
# global\
# if\
# import\
# in\
# is\
# lambda\
# nonlocal\
# None\
# not\
# or\
# pass\
# raise\
# return\
# True\
# try\
# with\
# while\
# yeild

# %% [markdown]
# print sum of two numbers
#
# a = 5\
# b = 10

# %%
a = 10
b = 5
sum = a + b , a-b , a * b , a / b
print(sum)
# Out:
# (15, 5, 50, 2.0)

# %% [markdown]
# **Type of Operators** \
# an operator is s symbol that performs a certain operation between operands\
#
#
#
# *   Arithmetic Operator : (+ , - , * , / , % , **)
# *   Relational / Comparison Operators : ( == , != , < , > ,  ,= ,  >=)
#
#
# *   List item
# *   List item
